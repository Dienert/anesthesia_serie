# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
val_results = pd.read_csv("resultados.csv")

# %% [markdown]
# ## Validation Results

# %%
val_results
# Out:
#      model  repetition     val_r2     val_mse    val_mae  \
# 0      KNN           4   0.983209    1.439349   0.037350
# 1      KNN           0   0.983207    1.439533   0.037225
# 2      KNN           3   0.983207    1.439533   0.037225
# 3      KNN           5   0.983207    1.439533   0.037225
# 4      KNN           7   0.983207    1.439533   0.037225
# 5      KNN           9   0.983207    1.439533   0.037225
# 6      KNN           6   0.983137    1.445448   0.033710
# 7      KNN           1   0.983133    1.445822   0.033512
# 8      KNN           2   0.983021    1.455326   0.029102
# 9      KNN           8   0.983019    1.455501   0.029029
# 10  KNN_d1           8 -77.529189  177.352946  10.014284
# 11  KNN_d1           1 -78.447863  177.240648  10.015082
# 12  KNN_d1           2 -80.356526  177.200951  10.015234
# 13  KNN_d1           7 -81.554656  177.181876  10.017990
# 14  KNN_d1           5 -83.735068  177.136351  10.017431
# ...

# %% [markdown]
# ## Test Results

# %%
test_results = pd.DataFrame([
                             {'model': 'KNN', 'R2': -17.476980899567987, 'mse': 32.07937470474599, 'mae': 3.3067287039251956},
                             {'model': 'SVR', 'R2': -28.08929454996452, 'mse': 32.02394361012353, 'mae': 3.2868086581257434},
                             {'model': 'ARIMA', 'R2':-29.760014158999827, 'mse': 29.22241238926236, 'mae': 3.357089072406653},
                             {'model': 'KNN-d1', 'R2': -88.46209485329223, 'mse': 177.01459173776482, 'mae': 10.009178101133497},
                             {'model': 'MLP', 'R2': -163.30316440835952, 'mse': 32.021915929347855, 'mae': 3.258952080475984},
                            ])
test_results
# Out:
#     model          R2         mse        mae
# 0     KNN  -17.476981   32.079375   3.306729
# 1     SVR  -28.089295   32.023944   3.286809
# 2   ARIMA  -29.760014   29.222412   3.357089
# 3  KNN-d1  -88.462095  177.014592  10.009178
# 4     MLP -163.303164   32.021916   3.258952
